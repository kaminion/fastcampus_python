# %%
데이터 = [-10, 10, 20]

def 양수판별(x):
    result = False
    if x > 0 : 
        result = True
    return result

# True인 값만 반환
list(filter(양수판별, 데이터))

데이터 = [10, 14, 4, 6, 19, 4]

list(filter(lambda x: 10 < x < 20 , 데이터))

# filter는 탐색용, 거르기 True인걸 거름
리스트 = ["kakaotalk.exe", 'test.txt']
list(filter(lambda x: x.split('.')[-1] == "exe", 리스트))


a = lambda x : 200 if x > 200 else x + 50
a(250)


import matplotlib.pyplot as plt
#y = x3 + 1 시각화

x = range(-4, 5, 1)
y = []
for val in x :
    y.append(val ** 3 + 1)
#plt.plot(x, y)

# 맵은 리스트마다 적용, mapping
리스트 = ["1,325", "32,444"]
결과 = list(map(lambda x : x.replace(',', ''), 리스트))

print(결과)


데이터 = [10, -10, -20, -40, -30, 30]
#
def my_filter(조건함수, 데이터):
    result = []
    for val in 데이터 :
        if 조건함수(val):
            result.append(val)
    return result
arr = my_filter(lambda x : x > 0, 데이터)
print(arr)


# try-except 에러처리

# try: 
#     price = int(input("금액"))
#     val = int(input("사람 수 : "))
#     div = price/val
# except ZeroDivisionError as c:
#     print(f"에러 발생 {c}")


class 클래스이름:
    def 통계학(self):
        print("통계학")
    def 경제학(self):
        print("경제학")
    def 정치학(self):
        print("정치학")


c = 클래스이름()
c.정치학()

class 예의바른학생:
    def 첫인사(self, 이름):
        print(f"안녕하세요 {이름}")
    def 작별인사(self):
        print("빠잉")

instance = 예의바른학생()
instance.첫인사('안중원')

example = 예의바른학생()
example.첫인사('안중원')


class 사람:
    def 정보입력(self, 이름, 나이, 지역):
        self.이름 = 이름
        self.나이 = 나이
        self.지역 = 지역
    def 정보출력(self):
        print(self.이름)
        print(self.나이)
        print(self.지역)

철수 = 사람()
철수.정보입력("김철수", 20, "서울")
철수.정보출력()

class blank
    pass
# Out:
# ['1325', '32444']
# [10, 30]
# 정치학
# 안녕하세요 안중원
# 안녕하세요 안중원
# 김철수
# 20
# 서울
